# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import random
import numpy as np
import tensorflow as tf
#---
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalizacion de los pixeles
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

#- Normalize pixel values to be between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

#- Convert labels to one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

#- Define the model architecture
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

#- Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#- Train the model
history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

#- Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test Accuracy:", test_acc)
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 25ms/step - accuracy: 0.3600 - loss: 1.7794 - val_accuracy: 0.5309 - val_loss: 1.3359
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.5500 - loss: 1.2819 - val_accuracy: 0.5790 - val_loss: 1.2232
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.6028 - loss: 1.1461 - val_accuracy: 0.5767 - val_loss: 1.1892
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.6312 - loss: 1.0615 - val_accuracy: 0.5899 - val_loss: 1.1872
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 29ms/step - accuracy: 0.6549 - loss: 0.9920 - val_accuracy: 0.6301 - val_loss: 1.0721
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 46ms/step - accuracy: 0.6767 - loss: 0.9349 - val_accuracy: 0.6306 - val_loss: 1.0692
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6899 - loss: 0.8864 - val_accuracy: 0.6339 - val_loss: 1.0683
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7070 - loss: 0.8438 - val_accuracy: 0.6253 - val_loss: 1.0871
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.7197 - loss: 0.8041 - val_accuracy: 0.6398 - val_loss: 1.0489
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.7345 - loss: 0.7600 - val_accuracy: 0.6496 - val_loss: 1.0336
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6511 - loss: 1.0175
# Test Accuracy: 0.6496000289916992

# %%
# Normalize pixel values to be between 0 and 1from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import to_categorical

# Load and preprocess the data
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# Convert labels to one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define the model architecture
model = models.Sequential()
model.add(layers.Conv2D(40, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

model.add(layers.Flatten())
model.add(layers.Dense(120, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test Accuracy:", test_acc)
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 30ms/step - accuracy: 0.3166 - loss: 1.8787 - val_accuracy: 0.4856 - val_loss: 1.4182
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.5123 - loss: 1.3648 - val_accuracy: 0.5442 - val_loss: 1.2753
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 24s 31ms/step - accuracy: 0.5650 - loss: 1.2337 - val_accuracy: 0.5586 - val_loss: 1.2323
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 29ms/step - accuracy: 0.5963 - loss: 1.1512 - val_accuracy: 0.5860 - val_loss: 1.1755
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - accuracy: 0.6143 - loss: 1.1070 - val_accuracy: 0.6076 - val_loss: 1.1151
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.6331 - loss: 1.0540 - val_accuracy: 0.6307 - val_loss: 1.0696
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.6537 - loss: 0.9983 - val_accuracy: 0.6379 - val_loss: 1.0421
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - accuracy: 0.6641 - loss: 0.9815 - val_accuracy: 0.6347 - val_loss: 1.0436
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 28ms/step - accuracy: 0.6720 - loss: 0.9485 - val_accuracy: 0.6377 - val_loss: 1.0328
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.6732 - loss: 0.9372 - val_accuracy: 0.6558 - val_loss: 1.0077
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6554 - loss: 0.9956
# Test Accuracy: 0.6557999849319458

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
import keras_tuner as kt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers

# Load and preprocess the data
(img_train, label_train), (img_test, label_test) = datasets.cifar10.load_data()

img_train = img_train.astype('float32') / 255.0
img_test = img_test.astype('float32') / 255.0

def model_builder(hp):
    model = keras.Sequential()
    model.add(layers.Conv2D(40, (3, 3), activation='relu', input_shape=(32, 32, 3)))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))
    model.add(layers.Flatten())
    
    hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
    model.add(layers.Dense(units=hp_units, activation='relu'))
    model.add(layers.Dense(120, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))  # 10 units for 10 classes with softmax activation

    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                  loss='sparse_categorical_crossentropy',  # Use sparse_categorical_crossentropy for integer labels
                  metrics=['accuracy'])
    return model

# Use RandomSearch tuner with max_trials set to 1 to perform only one search iteration
tuner = kt.RandomSearch(
    model_builder,
    objective='val_accuracy',
    max_trials=1,  # Set max_trials to 1
    directory='my_dir',
    project_name='intro_to_kt'
)

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# Perform the search
tuner.search(img_train, label_train, epochs=20, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the optimal hyperparameters and train it
model = tuner.hypermodel.build(best_hps)
history = model.fit(img_train, label_train, epochs=12, validation_split=0.2)

# Evaluate the model
score = model.evaluate(img_test, label_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Reloading Tuner from my_dir\intro_to_kt\tuner0.json
# Epoch 1/12
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.3361 - loss: 1.7902 - val_accuracy: 0.5143 - val_loss: 1.3570
# Epoch 2/12
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.5395 - loss: 1.2929 - val_accuracy: 0.5729 - val_loss: 1.2356
# Epoch 3/12
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.5866 - loss: 1.1692 - val_accuracy: 0.5924 - val_loss: 1.1604
# Epoch 4/12
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.6220 - loss: 1.0724 - val_accuracy: 0.5992 - val_loss: 1.1570
# Epoch 5/12
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.6489 - loss: 1.0104 - val_accuracy: 0.6176 - val_loss: 1.0946
# Epoch 6/12
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.6606 - loss: 0.9720 - val_accuracy: 0.6271 - val_loss: 1.0666
# Epoch 7/12
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.6715 - loss: 0.9352 - val_accuracy: 0.6278 - val_loss: 1.0641
# Epoch 8/12
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.6787 - loss: 0.9068 - val_accuracy: 0.6212 - val_loss: 1.1025
# Epoch 9/12
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - accuracy: 0.6906 - loss: 0.8794 - val_accuracy: 0.6155 - val_loss: 1.1098
# Epoch 10/12
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.7002 - loss: 0.8535 - val_accuracy: 0.6489 - val_loss: 1.0326
# Epoch 11/12
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.7087 - loss: 0.8396 - val_accuracy: 0.6381 - val_loss: 1.0837
# Epoch 12/12
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.7186 - loss: 0.8102 - val_accuracy: 0.6357 - val_loss: 1.0698
# Test loss: 1.0690011978149414
# Test accuracy: 0.6297000050544739
